# %% [markdown]
# <a href="https://colab.research.google.com/github/zoarpanjaitan/MH-DETECTION-WITH-LR/blob/main/cleaning_Text_eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path_1 = '/content/drive/MyDrive/DATASET/(2)eng_MH_tweet.csv'
df = pd.read_csv(file_path_1)
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1917855097071231365  Fri May 02 05:48:02 +0000 2025               0
# 1  1916344354676920597  Sun Apr 27 04:11:12 +0000 2025               0
# 2  1902615902857904435  Thu Mar 20 06:59:14 +0000 2025               7
# 3  1900308510090354693  Thu Mar 13 22:10:29 +0000 2025               2
# 4  1900307971881501009  Thu Mar 13 22:08:21 +0000 2025               0
#
#                                            full_text               id_str  \
# 0  @ChuoMoon Right like you do self harm and star...  1918180661820641608
# 1  CONG men/women given plenty of sketchy self de...  1916344354676920597
# 2  i know im a mentally ill zillennial but the id...  1902615902857904435
# 3  They are all mentally ill and unstable. Some e...  1900308510090354693
# 4  They are all mentally ill and unstable. Some e...  1900307971881501009
#
#   image_url in_reply_to_screen_name lang  location  quote_count  reply_count  \
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      50 non-null     int64
#  1   created_at               50 non-null     object
#  2   favorite_count           50 non-null     int64
#  3   full_text                50 non-null     object
#  4   id_str                   50 non-null     int64
#  5   image_url                3 non-null      object
#  6   in_reply_to_screen_name  15 non-null     object
#  7   lang                     50 non-null     object
#  8   location                 0 non-null      float64
#  9   quote_count              50 non-null     int64
#  10  reply_count              50 non-null     int64
#  11  retweet_count            50 non-null     int64
#  12  tweet_url                50 non-null     object
#  13  user_id_str              50 non-null     int64
# ...

# %%
drop_kolom = ['conversation_id_str', 'created_at', 'favorite_count', 'id_str', 'image_url', 'in_reply_to_screen_name', 'lang', 'location', 'quote_count','reply_count','retweet_count','tweet_url','user_id_str','username']
df_clean = df.drop(drop_kolom, axis=1)
df_clean.head(25)
# Out:
#                                             full_text
# 0   @ChuoMoon Right like you do self harm and star...
# 1   CONG men/women given plenty of sketchy self de...
# 2   i know im a mentally ill zillennial but the id...
# 3   They are all mentally ill and unstable. Some e...
# 4   They are all mentally ill and unstable. Some e...
# 5   Ma'am women like you are destroying yourselves...
# 6   also had a panic attack in front of my manger ...
# 7   do you also sob and have a panic attack becaus...
# 8   @farmingandJesus I self taught myself to not p...
# 9   Panic attack? Anxiety attack My brain is refus...
# 10  @thepeacepoet99 So basically... a woman has a ...
# 11  Note to self: If I ever make it on Survivor me...
# 12  being self aware mentally ill is so annoying b...
# 13  Im so sick and tired of waking up panicked eve...
# 14  I m so serious I m not okay mentally I have no...
# 15  @taesoothe I ️ because everything is over I ca...
# ...

# %%
df['full_text'] = df['full_text'].str.lower()

# %%
import re

def clean_tweet(text):
    text = re.sub(r"http\S+|www.\S+", "", text)              # URL
    text = re.sub(r"@\w+", "", text)                         # Mention
    text = re.sub(r"#\w+", "", text)                         # Hashtag
    text = re.sub(r"\brt\b", "", text)                       # Retweet
    text = re.sub(r"[^\w\s]", "", text)                      # Punctuation
    text = re.sub(r"\d+", "", text)                          # Numbers
    text = re.sub(r"\s+", " ", text).strip()                 # Extra spaces
    return text

df['clean_text'] = df['full_text'].apply(clean_tweet)

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

df['clean_text'] = df['clean_text'].apply(
    lambda x: " ".join([word for word in x.split() if word not in stop_words])
)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Out:
# 0     right like self harm starve clearly mental ill...
# 1     cong menwomen given plenty sketchy self declar...
# 2     know im mentally ill zillennial idea working s...
# 3     mentally ill unstable exhibit unstableness sel...
# 4     mentally ill unstable exhibit unstableness sel...
# 5     maam women like destroying self harm body atta...
# 6     also panic attack front manger cried mentally ...
# 7     also sob panic attack felt mentally tired u st...
# 8     self taught panic would freak heart rate went ...
# 9     panic attack anxiety attack brain refusing giv...
# 10    basically woman hyperfeminine reaction haircut...
# 11    note self ever make survivor mentally prepare ...
# 12    self aware mentally ill annoying wet weather m...
# 13    im sick tired waking panicked every morning im...
# 14    serious okay mentally hope tired strong five s...
# 15    everything cant stand much attack anymore im s...
# 16    might dying guys im coldsweating stomache hurt...
# ...

# %%
df['clean_text'].to_csv('(2)final_MH.csv', index=False)
